# %% [markdown]
# # Данные университетов в ИС [rosrid.ru](https://rosrid.ru/)
#
# Основная задача данного отчёта продемонстрировать каким образом можно взять данные по своему университету из информационной системы (сайта) [rosrid.ru](https://rosrid.ru/).
#
# Все механики будут показаны на примере одного университета — [Дальневосточный федеральный университет](https://t.me/psalgroup/10182).
#
# Каждый университет в рамках ИС имеет уникальный ID, по которому и будет осуществляться поиск по всем возможным объектам. На gif-ке ниже показано, каким образом можно узнать ID своего университета (все манипуляции происходят на странице [«Глобального поиска»](https://rosrid.ru/global-search)).
#
# ![](assets/get_university_id.gif)
#
# Зафиксируем данный параметр для ДВФУ, а также заведём переменные, которые ограничат нас текущим годом для поиска.

# %%
uid = '9944117'
start_date = '2022-01-01'
end_date = '2022-12-31'

# %% [markdown]
# Сначала воспроизведём основное, что нам понадобится в работе.

# %%
import requests

# URL API, который осуществляет поиск по ИС
search_url = 'https://rosrid.ru/api/base/search'
# Формируем заготовку для основного тела поиска
payload = {
    "search_query": None,
    "critical_technologies": [],
    "dissertations": False,
    "full_text_available": False,
    "ikrbses": False,
    "nioktrs": False,
    "organization": [uid],
    "page": 1,
    "priority_directions": [],
    "rids": False,
    "rubrics": [],
    "search_area": "Во всех полях",
    "sort_by": "Дата регистрации",
    "open_license": False,
    "free_licenses": False,
    "expert_estimation_exist": False,
    "start_date": start_date,
    "end_date": end_date
}

# Создаём сессию и проставляем стандартные заголовки, что бы не сильно отличаться от браузера
session = requests.session()
session.headers.update({
    'authority': 'rosrid.ru',
    'pragma': 'no-cache',
    'cache-control': 'no-cache',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="98", "Google Chrome";v="98"',
    'accept': 'application/json, text/plain, */*',
    'sec-ch-ua-mobile': '?0',
    'content-type': 'application/json;charset=UTF-8',
    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.80 Safari/537.36',
    'sec-ch-ua-platform': '"Linux"',
    'origin': 'https://rosrid.ru',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://rosrid.ru/global-search',
    'accept-language': 'ru,en-US;q=0.9,en;q=0.8,ru-RU;q=0.7'
})

# Для проверки подключаемся к странице поиска и возвращаем код ответа (должен быть 200)
home_resp = session.request('GET', 'https://rosrid.ru/global-search')
home_resp.status_code
# Out:
# 200

# %% [markdown]
# Т.к. результаты поиска выдаются в постраничном виде, реализуем функцию, которая позволит нам рекурсивно собрать весь объём данных.

# %%
import time
import json

def get_search_results(data, timeout=1):
    items_in_page = 10
    search_results = []

    try:
        resp = session.request("POST", search_url, data=json.dumps(data, ensure_ascii=False).encode('utf-8'))

        if resp.status_code == 200:
            json_resp = resp.json()
            page = data['page']
            total = json_resp['hits']['total']['value']
            count_of_pages = (int(total / items_in_page) + 1) if total % items_in_page else total / items_in_page

            print(f"Downloaded data from page {page} of {count_of_pages}")

            if page < count_of_pages:
                time.sleep(timeout)
                search_results += json_resp['hits']['hits'] + get_search_results({**data, 'page': page + 1}, timeout)
            else:
                search_results += json_resp['hits']['hits']
    except BaseException as e:
        print('Retry connection', str(e))
        search_results = get_search_results({**data, 'page': 1}, timeout)

    return search_results

# %% [markdown]
# ## НИОКТР
#
# Для начала заберём данные о НИОКТР-ах ДВФУ за 2022 год и посмотрим 5 первых записей.

# %%
import pandas as pd

pd.set_option('display.max_columns', None)

nioktrs = pd.json_normalize(get_search_results({**payload, 'nioktrs': True}))
nioktrs.dropna(axis=1).head(5)
# Out:
# Downloaded data from page 1 of 2
# Downloaded data from page 2 of 2
#     _index _type                       _id  _score                  sort  \
# 0  nioktrs  _doc  ZJP5EE4LCTKBP7PH060ZJJWR     0.0  [1661411639597, 0.0]
# 1  nioktrs  _doc  ZG7FZFSFZ5JU6Q1PLVWMVGXB     0.0  [1661411399139, 0.0]
# 2  nioktrs  _doc  C6ULS4ADTHJQ83675ME8CWEI     0.0  [1660896626635, 0.0]
# 3  nioktrs  _doc  4FTGJES27U8HFEV04DMVK86P     0.0  [1660118597080, 0.0]
# 4  nioktrs  _doc  YKXJGJTZ988W6F1A7FWRUK0U     0.0  [1660118577131, 0.0]
#
#                                         _source.name  \
# 0  Специализированные пищевые системы для профила...
# 1  Системы на основе биополимеров для доставки ле...
# 2  Исследование природных и антропогенных воздейс...
# 3  Использование подхода OSMAC (один штамм – мног...
# 4  Граничные эффекты в эпитаксиальных пленках [Pd...
#
#                                   _source.annotation  \
# 0  На основании полученных результатов будут спро...
# 1  Большинство препаратов, разрабатываемых для те...
# 2  Цель научного исследования – Оценка природных ...
# 3  В проекте в качестве объектов исследования буд...
# 4  В физике магнитных явлений в последние несколь...
#
#                                 _source.keyword_list  \
# 0  [{'name': 'восприятие потребителей'}, {'name':...
# 1  [{'name': 'наночастицы'}, {'name': 'биополимер...
# 2  [{'name': 'природные воздействия'}, {'name': '...
# 3  [{'name': 'биологически активные соединения'},...
# 4  [{'name': 'эпитаксиальные суперрешетки'}, {'na...
#
#   _source.work_supervisor.name _source.work_supervisor.surname  \
# 0                        Антон                        Табакаев
# 1                     Владимир                       Силантьев
# 2                       Кирилл                        Винников
# 3                        Елена                         Лещенко
# 4                      Алексей                          Козлов
#
#   _source.work_supervisor.patronymic  \
# 0                          Вадимович
# 1                         Евгеньевич
# 2                          Андреевич
# 3                      Владиславовна
# 4                        Гавриилович
#
#                     _source.work_supervisor.position  \
# 0  Доцент Департамента пищевых наук и технологий ...
# 1                                Заведующий кафедрой
# 2  Директор Института Мирового океана (школы), за...
# 3                                  Научный сотрудник
# 4                              Старший преподаватель
#
#   _source.organization_supervisor.name  \
# 0                            Александр
# 1                            Александр
# 2                            Александр
# 3                            Александр
# 4                            Александр
#
#   _source.organization_supervisor.surname  \
# 0                                Самардак
# 1                                Самардак
# 2                                Самардак
# 3                                Самардак
# 4                                Самардак
#
#   _source.organization_supervisor.patronymic  \
# 0                                  Сергеевич
# 1                                  Сергеевич
# 2                                  Сергеевич
# 3                                  Сергеевич
# 4                                  Сергеевич
#
#   _source.organization_supervisor.position       _source.executor.id  \
# 0              Проректор по научной работе  JXDYN5VUB7LATD8HZ4740PRS
# 1              Проректор по научной работе  JXDYN5VUB7LATD8HZ4740PRS
# 2              Проректор по научной работе  JXDYN5VUB7LATD8HZ4740PRS
# 3              Проректор по научной работе  JXDYN5VUB7LATD8HZ4740PRS
# 4              Проректор по научной работе  JXDYN5VUB7LATD8HZ4740PRS
#
#   _source.executor.organization_id  \
# 0          2e11cd14ccfce8a78646e73
# 1          2e11cd14ccfce8a78646e73
# 2          2e11cd14ccfce8a78646e73
# 3          2e11cd14ccfce8a78646e73
# 4          2e11cd14ccfce8a78646e73
#
#                                _source.executor.name  \
# 0  ФЕДЕРАЛЬНОЕ ГОСУДАРСТВЕННОЕ АВТОНОМНОЕ ОБРАЗОВ...
# 1  ФЕДЕРАЛЬНОЕ ГОСУДАРСТВЕННОЕ АВТОНОМНОЕ ОБРАЗОВ...
# 2  ФЕДЕРАЛЬНОЕ ГОСУДАРСТВЕННОЕ АВТОНОМНОЕ ОБРАЗОВ...
# 3  ФЕДЕРАЛЬНОЕ ГОСУДАРСТВЕННОЕ АВТОНОМНОЕ ОБРАЗОВ...
# 4  ФЕДЕРАЛЬНОЕ ГОСУДАРСТВЕННОЕ АВТОНОМНОЕ ОБРАЗОВ...
#
#                          _source.executor.short_name _source.executor.ogrn  \
# 0  ФГАОУ ВО "ДАЛЬНЕВОСТОЧНЫЙ ФЕДЕРАЛЬНЫЙ УНИВЕРСИ...         1022501297785
# 1  ФГАОУ ВО "ДАЛЬНЕВОСТОЧНЫЙ ФЕДЕРАЛЬНЫЙ УНИВЕРСИ...         1022501297785
# 2  ФГАОУ ВО "ДАЛЬНЕВОСТОЧНЫЙ ФЕДЕРАЛЬНЫЙ УНИВЕРСИ...         1022501297785
# 3  ФГАОУ ВО "ДАЛЬНЕВОСТОЧНЫЙ ФЕДЕРАЛЬНЫЙ УНИВЕРСИ...         1022501297785
# 4  ФГАОУ ВО "ДАЛЬНЕВОСТОЧНЫЙ ФЕДЕРАЛЬНЫЙ УНИВЕРСИ...         1022501297785
#
#   _source.executor.region.name _source.executor.region.code  \
# 0              Приморский край                           25
# 1              Приморский край                           25
# 2              Приморский край                           25
# 3              Приморский край                           25
# 4              Приморский край                           25
#
#                          _source.executor.okogu.name _source.coexecutors  \
# 0  Министерство науки и высшего образования Росси...                  []
# 1  Министерство науки и высшего образования Росси...                  []
# 2  Министерство науки и высшего образования Росси...                  []
# 3  Министерство науки и высшего образования Росси...                  []
# 4  Министерство науки и высшего образования Росси...                  []
#
#         _source.customer.id _source.customer.organization_id  \
# 0  107775997263010000000001          1e88d205da93af783d0d9da
# 1  107775997263010000000001          1e88d205da93af783d0d9da
# 2  089Y0A0LoDLV15JGaQ2cLb00          5f7f75ebf4703b53b50b78d
# 3  107775997263010000000001          1e88d205da93af783d0d9da
# 4  107775997263010000000001          1e88d205da93af783d0d9da
#
#                                _source.customer.name  \
# 0                            Российский научный фонд
# 1                            Российский научный фонд
# 2  МИНИСТЕРСТВО НАУКИ И ВЫСШЕГО ОБРАЗОВАНИЯ РОССИ...
# 3                            Российский научный фонд
# 4                            Российский научный фонд
#
#   _source.customer.short_name _source.customer.ogrn _source.nioktr_bases.name  \
# 0                         РНФ         1137799022261                     Грант
# 1                         РНФ         1137799022261                     Грант
# 2          МИНОБРНАУКИ РОССИИ         1187746579690   Государственное задание
# 3                         РНФ         1137799022261                     Грант
# 4                         РНФ         1137799022261                     Грант
#
#                          _source.nioktr_types  \
# 0  [{'name': 'Фундаментальное исследование'}]
# 1  [{'name': 'Фундаментальное исследование'}]
# 2  [{'name': 'Фундаментальное исследование'}]
# 3  [{'name': 'Фундаментальное исследование'}]
# 4  [{'name': 'Фундаментальное исследование'}]
#
#                      _source.priority_directions  \
# 0  [{'name': 'Рациональное природопользование'}]
# 1             [{'name': 'Индустрия наносистем'}]
# 2  [{'name': 'Рациональное природопользование'}]
# 3                    [{'name': 'Науки о жизни'}]
# 4             [{'name': 'Индустрия наносистем'}]
#
#                        _source.critical_technologies  \
# 0  [{'name': 'Биомедицинские и ветеринарные техно...
# 1  [{'name': 'Технологии получения и обработки ко...
# 2  [{'name': 'Технологии мониторинга и прогнозиро...
# 3  [{'name': 'Биокаталитические, биосинтетические...
# 4  [{'name': 'Технологии получения и обработки фу...
#
#                                      _source.budgets  \
# 0  [{'budget_type': {'name': 'Средства фондов под...
# 1  [{'budget_type': {'name': 'Средства фондов под...
# 2  [{'budget_type': {'name': 'Средства федерально...
# 3  [{'budget_type': {'name': 'Средства фондов под...
# 4  [{'budget_type': {'name': 'Средства фондов под...
#
#                                      _source.rubrics  \
# 0  [{'name': 'Отходы производства и их переработк...
# 1  [{'name': 'Структура и функции биополимеров', ...
# 2  [{'name': 'Экологическая токсикология', 'code'...
# 3  [{'name': 'Прочие природные соединения', 'code...
# 4  [{'name': 'Физика наноструктур. Низкоразмерные...
#
#                                        _source.oecds  \
# 0  [{'name': 'NUTRITION & DIETETICS', 'code': '03...
# 1  [{'name': 'NANOSCIENCE & NANOTECHNOLOGY', 'cod...
# 2          [{'name': 'ECOLOGY', 'code': '01.06.GU'}]
# 3  [{'name': 'CHEMISTRY, ORGANIC', 'code': '01.04...
# 4  [{'name': 'PHYSICS, CONDENSED MATTER', 'code':...
#
#    _source.last_status.created_date _source.last_status.registration_number  \
# 0  2022-08-25T07:13:59.597600+00:00                          122082500021-5
# 1  2022-08-25T07:09:59.139698+00:00                          122082500018-5
# 2  2022-08-19T08:10:26.635601+00:00                          122081900027-6
# 3  2022-08-10T08:03:17.080025+00:00                          122081000059-6
# 4  2022-08-10T08:02:57.131215+00:00                          122081000058-9
#
#    _source.number_of_related_rid _source.start_date _source.end_date  \
# 0                              0         2022-07-27       2024-06-30
# 1                              0         2022-07-29       2025-06-30
# 2                              0         2022-07-14       2022-12-30
# 3                              0         2022-07-27       2024-06-30
# 4                              0         2022-07-27       2024-06-30
#
#   _source.contract_number _source.contract_date  _source.reports_number  \
# 0             22-76-00008            2022-07-27                       2
# 1             22-73-10172            2022-07-29                       3
# 2       075-03-2022-114/4            2022-07-14                       1
# 3             22-73-00190            2022-07-27                       2
# 4             22-72-00090            2022-07-27                       2
#
#                _source.udk  _source.number_of_views
# 0  664:502.171;664:658.567                        0
# 1             577.1 577.15                        1
# 2                    574.4                        0
# 3             577.1 547.91                        0
# 4  538.97 539.216.2 539.23                        0

# %% [markdown]
# ## РИД
#
# Теперь заберём данные о РИД-ах ДВФУ за 2022 год и посмотрим 5 первых записей.

# %%
rids = pd.json_normalize(get_search_results({**payload, 'rids': True}))
rids.dropna(axis=1).head(5)
# Out:
# Downloaded data from page 1 of 3
# Downloaded data from page 2 of 3
# Downloaded data from page 3 of 3
#   _index _type                       _id  _score                  sort  \
# 0   rids  _doc  78WN77ITQGWNX440GF9HB1RZ     0.0  [1660902576886, 0.0]
# 1   rids  _doc  K2KTVRPU87TGWNU47PU3I0M5     0.0  [1659515854705, 0.0]
# 2   rids  _doc  B3DXA8MZF9CXPB3ZY792W0R0     0.0  [1659515837389, 0.0]
# 3   rids  _doc  IA00NIZJSITLLHS72XKNPRLS     0.0  [1659417918600, 0.0]
# 4   rids  _doc  927EMBI2IGUVIL0XUS9UD9B5     0.0  [1659417904679, 0.0]
#
#                                         _source.name  \
# 0  Нейронная сеть для поиска основных состояний  ...
# 1  Программа для трехмерного сканирования объекто...
# 2  Программа моделирования деталей гидрораспредел...
# 3  Программа для визуализации результатов работы ...
# 4  Программа для анализа работы алгоритма трехмер...
#
#                                 _source.keyword_list  \
# 0  [{'name': 'нейронная сеть'}, {'name': 'модели ...
# 1  [{'name': 'протяженные объекты сложной  формы'...
# 2  [{'name': '3d модель'}, {'name': 'компьютерное...
# 3  [{'name': 'визуализация результатов работы'}, ...
# 4  [{'name': 'анализ работы'}, {'name': 'протяжен...
#
#                                     _source.abstract  \
# 0  Программа предназначена для поиска конфигураци...
# 1  Программа для трехмерного сканирования объекто...
# 2  Высокопроизводительная программа для ЭВМ предн...
# 3  Программа для визуализации результатов работы ...
# 4  Программа для анализа работы алгоритма трехмер...
#
#         _source.customer.id _source.customer.organization_id  \
# 0  107775997263010000000001          1e88d205da93af783d0d9da
# 1  102250051035010000000001          ae07dddb6331eec7121e4fa
# 2  102250051035010000000001          ae07dddb6331eec7121e4fa
# 3  102250051035010000000001          ae07dddb6331eec7121e4fa
# 4  102250051035010000000001          ae07dddb6331eec7121e4fa
#
#                                _source.customer.name  \
# 0                            Российский научный фонд
# 1  Открытое акционерное общество "Арсеньевская ав...
# 2  Открытое акционерное общество "Арсеньевская ав...
# 3  Открытое акционерное общество "Арсеньевская ав...
# 4  Открытое акционерное общество "Арсеньевская ав...
#
#   _source.customer.short_name _source.customer.ogrn _source.customer.inn  \
# 0                         РНФ         1137799022261           7709473426
# 1          ОАО ААК "ПРОГРЕСС"         1022500510350           2501002394
# 2          ОАО ААК "ПРОГРЕСС"         1022500510350           2501002394
# 3          ОАО ААК "ПРОГРЕСС"         1022500510350           2501002394
# 4          ОАО ААК "ПРОГРЕСС"         1022500510350           2501002394
#
#   _source.rid_type.name _source.expected.name  \
# 0     Программа для ЭВМ           Исполнитель
# 1     Программа для ЭВМ           Исполнитель
# 2     Программа для ЭВМ           Исполнитель
# 3     Программа для ЭВМ           Исполнитель
# 4     Программа для ЭВМ           Исполнитель
#
#                                    _source.executors  \
# 0  [{'id': 'JXDYN5VUB7LATD8HZ4740PRS', 'organizat...
# 1  [{'id': 'JXDYN5VUB7LATD8HZ4740PRS', 'organizat...
# 2  [{'id': 'JXDYN5VUB7LATD8HZ4740PRS', 'organizat...
# 3  [{'id': 'JXDYN5VUB7LATD8HZ4740PRS', 'organizat...
# 4  [{'id': 'JXDYN5VUB7LATD8HZ4740PRS', 'organizat...
#
#                                      _source.authors  \
# 0  [{'name': 'Егор', 'surname': 'Васильев', 'patr...
# 1  [{'name': 'Михаил', 'surname': 'Бабич', 'patro...
# 2  [{'name': 'Сергей', 'surname': 'Гречанов', 'pa...
# 3  [{'name': 'Михаил', 'surname': 'Бабич', 'patro...
# 4  [{'name': 'Михаил', 'surname': 'Бабич', 'patro...
#
#   _source.work_supervisor.name _source.work_supervisor.surname  \
# 0                      Виталий                         Капитан
# 1                   Константин                            Змеу
# 2                   Константин                            Змеу
# 3                   Константин                            Змеу
# 4                   Константин                            Змеу
#
#   _source.work_supervisor.patronymic _source.work_supervisor.position  \
# 0                            Юрьевич                           Доцент
# 1                         Витальевич            Директор департамента
# 2                         Витальевич            Директор департамента
# 3                         Витальевич            Директор департамента
# 4                         Витальевич            Директор департамента
#
#   _source.organization_supervisor.name  \
# 0                            Александр
# 1                            Александр
# 2                            Александр
# 3                            Александр
# 4                            Александр
#
#   _source.organization_supervisor.surname  \
# 0                                Самардак
# 1                                Самардак
# 2                                Самардак
# 3                                Самардак
# 4                                Самардак
#
#   _source.organization_supervisor.patronymic  \
# 0                                  Сергеевич
# 1                                  Сергеевич
# 2                                  Сергеевич
# 3                                  Сергеевич
# 4                                  Сергеевич
#
#   _source.organization_supervisor.position  \
# 0              Проректор по научной работе
# 1              Проректор по научной работе
# 2              Проректор по научной работе
# 3              Проректор по научной работе
# 4              Проректор по научной работе
#
#                                        _source.oecds  \
# 0  [{'name': 'PHYSICS, ATOMIC, MOLECULAR & CHEMIC...
# 1  [{'name': 'ENGINEERING, AEROSPACE', 'code': '0...
# 2  [{'name': 'ENGINEERING, AEROSPACE', 'code': '0...
# 3  [{'name': 'ENGINEERING, AEROSPACE', 'code': '0...
# 4  [{'name': 'ENGINEERING, AEROSPACE', 'code': '0...
#
#                                      _source.rubrics  \
# 0  [{'name': 'Автоматизация физического экспериме...
# 1  [{'name': 'Применение роботов и манипуляторов'...
# 2  [{'name': 'Технология авиастроения', 'code': '...
# 3  [{'name': 'Применение роботов и манипуляторов'...
# 4  [{'name': 'Применение роботов и манипуляторов'...
#
#    _source.last_status.created_date _source.last_status.registration_number  \
# 0  2022-08-19T09:49:36.886357+00:00                          622081900049-3
# 1  2022-08-03T08:37:34.705887+00:00                          622080300025-6
# 2  2022-08-03T08:37:17.389516+00:00                          622080300024-9
# 3  2022-08-02T05:25:18.600050+00:00                          622080200011-0
# 4  2022-08-02T05:25:04.679042+00:00                          622080200010-3
#
#    _source.additional_files _source.iksi  \
# 0                      True           []
# 1                     False           []
# 2                     False           []
# 3                     False           []
# 4                     False           []
#
#                                        _source.ikspo  \
# 0                                                 []
# 1  [{'last_status': {'created_date': '2022-08-19T...
# 2  [{'last_status': {'created_date': '2022-08-19T...
# 3  [{'last_status': {'created_date': '2022-08-19T...
# 4  [{'last_status': {'created_date': '2022-08-19T...
#
#    _source.rid_own_using_exists  _source.rid_external_using_exists  \
# 0                         False                              False
# 1                         False                              False
# 2                         False                              False
# 3                         False                              False
# 4                         False                              False
#
#   _source.used_rids                                 _source.using_ways  \
# 0                []  Научные исследования в области теории конденси...
# 1                []                      Промышленное 3d- сканирование
# 2                []                      машиностроение и судостроение
# 3                []                      Промышленное 3d- сканирование
# 4                []                      Промышленное 3d -сканирование
#
#    _source.number_of_prototypes  _source.number_of_views
# 0                             5                        0
# 1                             5                        0
# 2                             6                        0
# 3                             4                        0
# 4                             5                        0

# %% [markdown]
# ## Диссертации
#
# Последний набор данных будет содержать информацию о диссертациях связанных с ДВФУ.

# %%
dissertations = pd.json_normalize(get_search_results({**payload, 'dissertations': True}))
dissertations.dropna(axis=1).head(5)
# Out:
# Downloaded data from page 1 of 1
#           _index _type                       _id  _score  \
# 0  dissertations  _doc  NUCPVIPPBEKK7LKTPWKF95M6     0.0
# 1  dissertations  _doc  J6PJQH8V1SZT4YM64CSFEPJX     0.0
# 2  dissertations  _doc  3AX35XAG6XUG4XXBDO4X9UAZ     0.0
# 3  dissertations  _doc  I28IKOP0NHBPTI8I43ZHIQZV     0.0
#
#                    sort                                       _source.name  \
# 0  [1657719740396, 0.0]  Научное и практическое обоснование получения э...
# 1  [1657542275886, 0.0]  Цифровые системы связи и навигации в нестацион...
# 2  [1657270037839, 0.0]  Обоснование и разработка технологии обогащенны...
# 3  [1643202871206, 0.0]  Разработка оболочечной структуры аппаратно-про...
#
#                                 _source.keyword_list  \
# 0  [{'name': 'отходы ГПК и ТЭК'}, {'name': 'утили...
# 1  [{'name': 'гидроакустическая связь'}, {'name':...
# 2  [{'name': 'функциональные и обогащенные мясные...
# 3  [{'name': 'компьютерное зрение'}, {'name': 'мо...
#
#                                     _source.abstract  \
# 0  В работе приведены данные по утилизации отсево...
# 1  Современное освоение Мирового Океана неразрывн...
# 2  Объекты: биологически активные препараты - вит...
# 3  Диссертационная работа на тему «Разработка обо...
#
#   _source.dissertation_type.name _source.dissertation_report_type.name  \
# 0                     Докторская                              Рукопись
# 1                     Докторская                              Рукопись
# 2                   Кандидатская                              Рукопись
# 3                   Кандидатская                              Рукопись
#
#   _source.degree_pursued.name _source.protection_organization.id  \
# 0     Доктор технических наук           JXDYN5VUB7LATD8HZ4740PRS
# 1     Доктор технических наук           JXDYN5VUB7LATD8HZ4740PRS
# 2   Кандидат технических наук           JXDYN5VUB7LATD8HZ4740PRS
# 3   Кандидат технических наук           JXDYN5VUB7LATD8HZ4740PRS
#
#   _source.protection_organization.organization_id  \
# 0                         2e11cd14ccfce8a78646e73
# 1                         2e11cd14ccfce8a78646e73
# 2                         2e11cd14ccfce8a78646e73
# 3                         2e11cd14ccfce8a78646e73
#
#                 _source.protection_organization.name  \
# 0  ФЕДЕРАЛЬНОЕ ГОСУДАРСТВЕННОЕ АВТОНОМНОЕ ОБРАЗОВ...
# 1  ФЕДЕРАЛЬНОЕ ГОСУДАРСТВЕННОЕ АВТОНОМНОЕ ОБРАЗОВ...
# 2  ФЕДЕРАЛЬНОЕ ГОСУДАРСТВЕННОЕ АВТОНОМНОЕ ОБРАЗОВ...
# 3  ФЕДЕРАЛЬНОЕ ГОСУДАРСТВЕННОЕ АВТОНОМНОЕ ОБРАЗОВ...
#
#           _source.protection_organization.short_name  \
# 0  ФГАОУ ВО "ДАЛЬНЕВОСТОЧНЫЙ ФЕДЕРАЛЬНЫЙ УНИВЕРСИ...
# 1  ФГАОУ ВО "ДАЛЬНЕВОСТОЧНЫЙ ФЕДЕРАЛЬНЫЙ УНИВЕРСИ...
# 2  ФГАОУ ВО "ДАЛЬНЕВОСТОЧНЫЙ ФЕДЕРАЛЬНЫЙ УНИВЕРСИ...
# 3  ФГАОУ ВО "ДАЛЬНЕВОСТОЧНЫЙ ФЕДЕРАЛЬНЫЙ УНИВЕРСИ...
#
#   _source.protection_organization.ogrn _source.protection_organization.inn  \
# 0                        1022501297785                          2536014538
# 1                        1022501297785                          2536014538
# 2                        1022501297785                          2536014538
# 3                        1022501297785                          2536014538
#
#   _source.protection_organization.region.name  \
# 0                             Приморский край
# 1                             Приморский край
# 2                             Приморский край
# 3                             Приморский край
#
#   _source.protection_organization.region.code _source.author_organization.id  \
# 0                                          25       ALEQVRVDWUZEG0AZ8HV7WSWM
# 1                                          25       JXDYN5VUB7LATD8HZ4740PRS
# 2                                          25       102250191506110000000001
# 3                                          25       102250225950410000000001
#
#   _source.author_organization.organization_id  \
# 0                     d4ab74d492bdf940ff8d9bf
# 1                     2e11cd14ccfce8a78646e73
# 2                     d8c6fe537dca9cb3d35ea0b
# 3                     f6b210010a3093b1366c1b8
#
#                     _source.author_organization.name  \
# 0  ФЕДЕРАЛЬНОЕ ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБРАЗОВА...
# 1  ФЕДЕРАЛЬНОЕ ГОСУДАРСТВЕННОЕ АВТОНОМНОЕ ОБРАЗОВ...
# 2  Федеральное государственное бюджетное образова...
# 3  Федеральное государственное бюджетное образова...
#
#               _source.author_organization.short_name  \
# 0                                    ФГБОУ ВО ИРГУПС
# 1  ФГАОУ ВО "ДАЛЬНЕВОСТОЧНЫЙ ФЕДЕРАЛЬНЫЙ УНИВЕРСИ...
# 2                             ФГБОУ ВО "Дальрыбвтуз"
# 3                      МГУ им. адм. Г.И. Невельского
#
#   _source.author_organization.ogrn _source.author_organization.inn  \
# 0                    1023801748761                      3812010086
# 1                    1022501297785                      2536014538
# 2                    1022501915061                      2538008586
# 3                    1022502259504                      2540009788
#
#   _source.author_organization.region.name  \
# 0                           Иркутская обл
# 1                         Приморский край
# 2                         Приморский край
# 3                         Приморский край
#
#   _source.author_organization.region.code  \
# 0                                      38
# 1                                      25
# 2                                      25
# 3                                      25
#
#   _source.chairman_dissertation_council.name  \
# 0                                    Валерий
# 1                                    Валерий
# 2                                     Эдуард
# 3                                     Любовь
#
#   _source.chairman_dissertation_council.surname  \
# 0                                       Петухов
# 1                                       Петухов
# 2                                           Ким
# 3                                      Стаценко
#
#   _source.chairman_dissertation_council.patronymic  \
# 0                                         Иванович
# 1                                         Иванович
# 2                                       Николаевич
# 3                                      Григорьевна
#
#   _source.chairman_dissertation_council.position  \
# 0                                      Профессор
# 1                                      Профессор
# 2                            заведующий кафедрой
# 3                                      профессор
#
#   _source.chairman_dissertation_council.degree.name  \
# 0                           Доктор технических наук
# 1                           Доктор технических наук
# 2                           Доктор технических наук
# 3                 Доктор физико-математических наук
#
#   _source.organization_supervisor.name  \
# 0                            Александр
# 1                            Александр
# 2                            Александр
# 3                            Александр
#
#   _source.organization_supervisor.surname  \
# 0                                Самардак
# 1                                Самардак
# 2                                Самардак
# 3                                Самардак
#
#   _source.organization_supervisor.patronymic  \
# 0                                  Сергеевич
# 1                                  Сергеевич
# 2                                  Сергеевич
# 3                                  Сергеевич
#
#   _source.organization_supervisor.position  \
# 0              Проректор по научной работе
# 1              Проректор по научной работе
# 2              Проректор по научной работе
# 3              Проректор по научной работе
#
#                             _source.speciality_codes  \
# 0          [{'name': 'Экология', 'code': '1.5.15.'}]
# 1  [{'name': 'Физические поля корабля, океана, ат...
# 2  [{'name': 'Биотехнология пищевых продуктов и б...
# 3  [{'name': 'Физические поля корабля, океана, ат...
#
#                                      _source.rubrics  \
# 0  [{'name': 'Отходы производства и их использова...
# 1  [{'name': 'Аппаратура передачи данных', 'code'...
# 2  [{'name': 'Сырье. Заменители традиционного сыр...
# 3  [{'name': 'Применение авиации и авиационной те...
#
#                                        _source.oecds  \
# 0  [{'name': 'MATERIALS SCIENCE, COMPOSITES', 'co...
# 1        [{'name': 'ACOUSTICS', 'code': '01.03.AA'}]
# 2  [{'name': 'FOOD SCIENCE & TECHNOLOGY', 'code':...
# 3  [{'name': 'ROBOTICS', 'code': '02.02.RB'}, {'n...
#
#    _source.last_status.created_date _source.last_status.registration_number  \
# 0  2022-07-13T13:42:20.396027+00:00                          522071300157-3
# 1  2022-07-11T12:24:35.886027+00:00                          522071100113-1
# 2  2022-07-08T08:47:17.839262+00:00                          422070800101-5
# 3  2022-01-26T13:14:31.206652+00:00                          422012600051-5
#
#                                  _source.supervisors  \
# 0  [{'fio': 'Руш Е.А.', 'scientific_degree': {'na...
# 1  [{'fio': 'Стаценко Л.Г.', 'scientific_degree':...
# 2  [{'fio': 'Слуцкая, Т.Н.', 'scientific_degree':...
# 3  [{'fio': 'Букин О.А.', 'scientific_degree': {'...
#
#                                    _source.opponents _source.protection_date  \
# 0  [{'fio': 'Шершнева М.В.', 'scientific_degree':...              2022-07-06
# 1  [{'fio': 'Селезнев И.А.', 'scientific_degree':...              2022-06-23
# 2  [{'fio': 'Баженова, Б.А.', 'scientific_degree'...              2022-06-22
# 3  [{'fio': 'Павлов А.Н.', 'scientific_degree': {...              2022-01-17
#
#   _source.author_surname _source.author_name _source.author_patronymic  \
# 0             Коновалова             Наталия               Анатольевна
# 1               Родионов           Александр                   Юрьевич
# 2               Буракова               Елена              Владимировна
# 3             Коровецкий               Денис                 Андреевич
#
#    _source.tables_count  _source.pictures_count _source.bibliography  \
# 0                    73                      60                  657
# 1                    27                     123                  317
# 2                    56                       9                  160
# 3                    11                      83                   94
#
#    _source.applications_count  _source.pages_count  _source.sources_count  \
# 0                           2                  373                    657
# 1                           7                  352                    317
# 2                           9                  126                    178
# 3                           0                  145                     94
#
#    _source.books_count                          _source.udk  \
# 0                    1           502.174.1 658.567 628.3/.4
# 1                    1                   621.384.3; 681.883
# 2                    1                     637.523; 637.525
# 3                    1  543.082/.084:54-14; 544.01.082/.084
#
#    _source.transmission_to_third_party_users  _source.number_of_views
# 0                                      False                        2
# 1                                      False                        2
# 2                                      False                        1
# 3                                      False                       11
